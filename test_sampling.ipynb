# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Gift_Cards_embeddings.csv')
print(df.size)
n = 100

sampled_df = df.sample(n=n, random_state=42).reset_index(drop=True)
# Out:
# 9674

# %%
sampled_df.head()
# Out:
#   main_category                                              title  \
# 0    Gift Cards            AMC Theatre  Gift Cards, Multipack of 3
# 1    Gift Cards                          Subway Multi Pk Gift Card
# 2    Gift Cards                                 Baby Gap Gift Card
# 3    Gift Cards                                 Fazoli's Gift Card
# 4    Gift Cards  Amazon.com Gift Card in a Black Gift Box (Cong...
#
#    average_rating  rating_number  \
# 0             4.8            876
# 1             4.8            738
# 2             4.8            107
# 3             4.8            163
# 4             4.7            305
#
#                                             features  \
# 0  ['Redemption: Instore and Online'\n 'No return...
# 1  ['This Subway Card can be loaded with a dollar...
# 2  ['The Gift Card may be redeemed for merchandis...
# 3  ["The Fazoli's Gift Card is good toward any pu...
# 4  ['Gift Card is affixed inside a gift box'\n 'G...
#
# ...

# %%
sampled_df_2 = df.sample(n=n, random_state=42).reset_index(drop=True)
sampled_df_2.head()
# Out:
#   main_category                                              title  \
# 0    Gift Cards            AMC Theatre  Gift Cards, Multipack of 3
# 1    Gift Cards                          Subway Multi Pk Gift Card
# 2    Gift Cards                                 Baby Gap Gift Card
# 3    Gift Cards                                 Fazoli's Gift Card
# 4    Gift Cards  Amazon.com Gift Card in a Black Gift Box (Cong...
#
#    average_rating  rating_number  \
# 0             4.8            876
# 1             4.8            738
# 2             4.8            107
# 3             4.8            163
# 4             4.7            305
#
#                                             features  \
# 0  ['Redemption: Instore and Online'\n 'No return...
# 1  ['This Subway Card can be loaded with a dollar...
# 2  ['The Gift Card may be redeemed for merchandis...
# 3  ["The Fazoli's Gift Card is good toward any pu...
# 4  ['Gift Card is affixed inside a gift box'\n 'G...
#
# ...

# %%
filtered_df = df[df['main_category'] == 'Gift Cards']

# Display the first few rows of the filtered DataFrame
filtered_df.head()
# Out:
#   main_category                                              title  \
# 0    Gift Cards  Amazon.com Gift Card in Gift Tag (Various Desi...
# 1    Gift Cards  $25 Mastercard Gift Card (plus $3.95 Purchase ...
# 2    Gift Cards                   Tractor Supply Company Gift Card
# 3    Gift Cards                                  Staples Gift Card
# 4    Gift Cards                  Ninety Nine Restaurants Gift Card
#
#    average_rating  rating_number  \
# 0             4.8           1006
# 1             2.5             11
# 2             4.9           2708
# 3             4.8            351
# 4             4.8            443
#
#                                             features  \
# 0  ['Gift Card is affixed inside a gift tag'\n 'G...
# 1  ['This card is non-reloadable. No expiration o...
# 2  ['Tractor Supply Company is the largest operat...
# 3  ['Staples Gift Cards - Giving the perfect gift...
# 4  ['Ninety Nine Restaurants are a comfortable pl...
#
# ...
